# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
langs = ["Python", "C++", "Java", "C#", "Go"]
votes = [50, 24, 14, 6, 17]
explodes = [0, 0, 0, 0.2, 0]

# %%
plt.pie(votes, labels=langs, explode=explodes, autopct="%.2f%%", pctdistance=0.4, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c86da85f40>,
# ...
#  [Text(-1.086699599490348, 0.17054026054723181, 'Python'),
#   Text(0.39565761775935304, -1.0263795835406089, 'C++'),
#   Text(1.0910904828506338, -0.13971956997060678, 'Java'),
#   Text(1.176901032282621, 0.5521810936749839, 'C#'),
#   Text(0.509073726682436, 0.9751122708702094, 'Go')],
#  [Text(-0.3951634907237629, 0.06201464019899339, '45.05%'),
#   Text(0.14387549736703747, -0.37322893946931235, '21.62%'),
#   Text(0.3967601755820486, -0.05080711635294791, '12.61%'),
#   Text(0.5431850918227481, 0.25485281246537717, '5.41%'),
#   Text(0.1851177187936131, 0.35458628031643974, '15.32%')])
