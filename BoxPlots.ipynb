# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
heights = np.random.normal(172, 8, 300)

# %%
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2b0f9638410>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2b0f96389e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2b0f9638200>],
#  'medians': [<matplotlib.lines.Line2D at 0x2b0f9638fb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2b0f96392b0>],
#  'means': []}
