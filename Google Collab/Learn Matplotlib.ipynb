# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
x_data = np.random.random(50) * 100
y_data = np.random.random(50) * 100

# %%
plt.scatter(x_data, y_data, c='r', marker='*', s=150, alpha=0.5)

# %%
years = [2006 + x for x in range(16)]
weight = [5, 68, 9, 21, 95, 24, 76, 78, 91, 76, 34, 18, 47, 0, 91, 11]

plt.plot(years, weight, c="r", lw=5, linestyle="--")

# %%
years = [2006 + x for x in range(16)]
weight = [5, 68, 9, 21, 95, 24, 76, 78, 91, 76, 34, 18, 47, 0, 91, 11]

plt.scatter(years, weight)

# %%
years = [2006 + x for x in range(16)]
weight = [5, 68, 9, 21, 95, 24, 76, 78, 91, 76, 34, 18, 47, 0, 91, 11]

plt.plot(years, weight, "r--", lw=3)

# %%
x = ["C++", "C#", "Python", "Java", "JavaSceript"]
y = [20, 50, 140, 1, 45]

plt.bar(x, y, color="r", align="edge", width=0.5, edgecolor="green", lw=6)
# Out:
# <BarContainer object of 5 artists>

# %%
ages = np.random.normal(20, 1.5, 1000)
# plt.hist(ages, bins=20, color="b")
plt.hist(ages, bins=[ages.min(), 18, 21, ages.max()], color="b")
# Out:
# (array([ 68., 662., 270.]),
#  array([15.44014228, 18.        , 21.        , 24.76791396]),
#  <BarContainer object of 3 artists>)

# %%
ages = np.random.normal(20, 1.5, 1000)
plt.hist(ages, bins=20, color="b")
# Out:
# (array([  3.,   5.,   9.,  14.,  32.,  62.,  68.,  66.,  76., 112.,  98.,
#         117., 100.,  58.,  77.,  41.,  30.,  11.,  12.,   9.]),
#  array([15.78366503, 16.19182253, 16.59998002, 17.00813751, 17.41629501,
#         17.8244525 , 18.23261   , 18.64076749, 19.04892498, 19.45708248,
#         19.86523997, 20.27339746, 20.68155496, 21.08971245, 21.49786995,
#         21.90602744, 22.31418493, 22.72234243, 23.13049992, 23.53865741,
#         23.94681491]),
#  <BarContainer object of 20 artists>)

# %%
ages = np.random.normal(20, 1.5, 1000)
plt.hist(ages, bins=20, color="b", cumulative=True)
# Out:
# (array([   1.,    7.,   17.,   39.,   75.,  129.,  220.,  332.,  433.,
#          578.,  707.,  797.,  875.,  926.,  953.,  981.,  993.,  998.,
#          998., 1000.]),
#  array([15.40898725, 15.89006253, 16.37113782, 16.8522131 , 17.33328839,
#         17.81436367, 18.29543896, 18.77651424, 19.25758953, 19.73866481,
#         20.2197401 , 20.70081538, 21.18189067, 21.66296595, 22.14404124,
#         22.62511653, 23.10619181, 23.5872671 , 24.06834238, 24.54941767,
#         25.03049295]),
#  <BarContainer object of 20 artists>)

# %%
langs = ["C++", "C#", "Python", "Java", "JavaSceript"]
votes = [20, 50, 140, 35, 45]
explodes = [0.3, 0, 0, 0, 0]

plt.pie(votes, labels=langs, explode=explodes, shadow=True, autopct="%.2f%%", pctdistance=0.8, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5d525a7e80>,
# ...
#  [Text(-0.30095861519187384, 1.3672687782370334, 'C++'),
#   Text(-0.9104579029550225, 0.6173057645500674, 'C#'),
#   Text(-0.11893093262323164, -1.0935517515259023, 'Python'),
#   Text(1.0742826225417954, 0.23646743307424478, 'Java'),
#   Text(0.515249356936158, 0.971863210630424, 'JavaSceript')],
#  [Text(-0.23646748336504375, 1.0742826114719548, '6.90%'),
#   Text(-0.6621512021491073, 0.4489496469455035, '17.24%'),
#   Text(-0.08649522372598664, -0.7953103647461107, '48.28%'),
#   Text(0.7812964527576693, 0.1719763149630871, '12.07%'),
#   Text(0.37472680504447853, 0.7068096077312175, '15.52%')])

# %%
heights = np.random.normal(172, 8, 300)

plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcc19e4c670>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcc19e4d720>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcc1a852950>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcc19e4dd80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcc19e4eb60>],
#  'means': []}

# %%
first = np.linspace(0, 10, 25)
second = np.linspace(10, 200, 25)
third = np.linspace(200, 210, 25)
fourth = np.linspace(210, 230, 25)

data = np.concatenate([first, second, third, fourth])

plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcc19f78d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fcc19f7bf10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcc19f7b040>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcc08dc8ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcc08dc87c0>],
#  'means': []}

# %%
years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
income = [55, 56, 62, 61, 72, 72, 73, 75]

income_ticks = list(range(50, 81, 2))
plt.plot(years, income, c="r", lw=3)

plt.title("Income Growth", fontsize=30, fontname="FreeSerif")
plt.xlabel("Years")
plt.ylabel("Income")

plt.yticks(income_ticks, [f"${x}k USD" for x in income_ticks])
# Out:
# ([<matplotlib.axis.YTick at 0x7fcc08285a20>,
# ...
#  [Text(0, 50, '$50k USD'),
#   Text(0, 52, '$52k USD'),
#   Text(0, 54, '$54k USD'),
#   Text(0, 56, '$56k USD'),
#   Text(0, 58, '$58k USD'),
#   Text(0, 60, '$60k USD'),
#   Text(0, 62, '$62k USD'),
#   Text(0, 64, '$64k USD'),
#   Text(0, 66, '$66k USD'),
#   Text(0, 68, '$68k USD'),
#   Text(0, 70, '$70k USD'),
#   Text(0, 72, '$72k USD'),
#   Text(0, 74, '$74k USD'),
#   Text(0, 76, '$76k USD'),
#   Text(0, 78, '$78k USD'),
#   Text(0, 80, '$80k USD')])
# WARNING:matplotlib.font_manager:findfont: Font family 'FreeSerif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'FreeSerif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'FreeSerif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'FreeSerif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'FreeSerif' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'FreeSerif' not found.

# %%
stock_a = [100, 102, 99, 101, 101, 100, 102]
stock_b = [90, 95, 102, 104, 105, 103, 109]
stock_c = [110, 115, 100, 105, 100, 100, 98, 95]

plt.plot(stock_a, label="Stock A")
plt.plot(stock_b, label="Stock B")
plt.plot(stock_c, label="Stock C")

plt.legend(loc="lower center")

# %%
votes = [10, 2, 5, 16, 22]
people = ["A", "B", "C", "D", "E"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

# %%
# style.use("ggplot")
style.use("dark_background")

votes = [10, 2, 5, 16, 22]
people = ["A", "B", "C", "D", "E"]

plt.pie(votes, labels=None)
plt.legend(labels=people)

# %%
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
# https://matplotlib.org/stable/users/explain/customizing.html

# %%
x1, y1 = np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

# %%
plt.figure(1)
plt.scatter(x1, y1)

# %%
plt.figure(2)
plt.plot(x2, y2)

# %%
x = np.arange(100)
fig, axs = plt.subplots(2,2)

axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title("Sine Wave")

axs[0, 1].plot(x, np.cos(x))
axs[0, 1].set_title("Cosine Wave")

axs[1, 0].plot(x, np.random.random(100))
axs[1, 0].set_title("Random Function")

axs[1, 1].plot(x, np.log(x))
axs[1, 1].set_title("Logarithmic Function")
axs[1, 1].set_xlabel("TEST")

fig.suptitle("Four Subplots")
plt.savefig("four plots.png", dpi=300, transparent=True)
# Out:
# <ipython-input-10-e22673556386>:13: RuntimeWarning: divide by zero encountered in log
#   axs[1, 1].plot(x, np.log(x))

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

x = np.random.random(100)
y = np.random.random(100)
z = np.random.random(100)

ax.scatter(x, y, z)

ax.set_xlabel("3D Plot")
ax.set_ylabel("Test")
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

x = np.arange(0, 50, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.scatter(x, y, z)

ax.set_xlabel("3D Plot")
ax.set_ylabel("Test")
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

x = np.arange(0, 50, 0.1)
y = np.arange(0, 50, 0.1)
z = np.cos(x + y)

ax.scatter(x, y, z)

ax.set_xlabel("3D Plot")
ax.set_ylabel("Test")
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z)
ax.set_xlabel("3D Plot")
ax.set_ylabel("Test")
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap="Spectral")
ax.set_xlabel("3D Plot")
ax.set_ylabel("Test")

ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")

x = np.arange(-5, 5, 0.1)
y = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap="Spectral")
ax.set_xlabel("3D Plot")
ax.set_ylabel("Test")
ax.view_init(azim=0, elev=90)
ax.set_zlabel("Z")
# Out:
# Text(0.5, 0, 'Z')
